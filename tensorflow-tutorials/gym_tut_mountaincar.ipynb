# %%
import gymnasium as gym
import os
import sys
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from datetime import datetime
from sklearn.pipeline import FeatureUnion
from sklearn.preprocessing import StandardScaler
from sklearn.kernel_approximation import RBFSampler
from sklearn.linear_model import SGDRegressor

print(gym.__version__)
# Out:
# 0.29.1

# %%
class FeatureTransformer:
  def __init__(self, env, n_components=500):
    observation_examples = np.array([env.observation_space.sample() for x in range(10000)])
    scaler = StandardScaler()
    scaler.fit(observation_examples)

    # Used to converte a state to a featurizes represenation.
    # We use RBF kernels with different variances to cover different parts of the space
    featurizer = FeatureUnion([
            ("rbf1", RBFSampler(gamma=5.0, n_components=n_components)),
            ("rbf2", RBFSampler(gamma=2.0, n_components=n_components)),
            ("rbf3", RBFSampler(gamma=1.0, n_components=n_components)),
            ("rbf4", RBFSampler(gamma=0.5, n_components=n_components))
            ])
    example_features = featurizer.fit_transform(scaler.transform(observation_examples))

    self.dimensions = example_features.shape[1]
    self.scaler = scaler
    self.featurizer = featurizer

  def transform(self, observations):
    # print "observations:", observations
    scaled = self.scaler.transform(observations)
    # assert(len(scaled.shape) == 2)
    return self.featurizer.transform(scaled)

# %%
# Holds one SGDRegressor for each action
class Model:
  def __init__(self, env, feature_transformer, learning_rate):
    self.env = env
    self.models = []
    self.feature_transformer = feature_transformer
    for i in range(env.action_space.n):
      model = SGDRegressor(learning_rate=learning_rate)
      observation, _ = env.reset()
      model.partial_fit(feature_transformer.transform( [observation] ), [0])
      self.models.append(model)

  def predict(self, s):
    X = self.feature_transformer.transform([s])
    result = np.stack([m.predict(X) for m in self.models]).T
    assert(len(result.shape) == 2)
    return result

  def update(self, s, a, G):
    X = self.feature_transformer.transform([s])
    assert(len(X.shape) == 2)
    self.models[a].partial_fit(X, [G])

  def sample_action(self, s, eps):
    # eps = 0
    # Technically, we don't need to do epsilon-greedy
    # because SGDRegressor predicts 0 for all states
    # until they are updated. This works as the
    # "Optimistic Initial Values" method, since all
    # the rewards for Mountain Car are -1.
    if np.random.random() < eps:
      return self.env.action_space.sample()
    else:
      return np.argmax(self.predict(s))

# %%
# returns a list of states_and_rewards, and the total reward
def play_one(model, env, eps, gamma):
    observation, _ = env.reset()
    done = False
    totalreward = 0
    iters = 0
    while not done and iters < 10000:
        action = model.sample_action(observation, eps)
        prev_observation = observation
        observation, reward, done, info, _ = env.step(action)

    # update the model
    if done:
        G = reward
    else:
        Qnext = model.predict(observation)
        # assert(next.shape == (1, env.action_space.n))
        G = reward + gamma*np.max(Qnext[0])

    model.update(prev_observation, action, G)

    totalreward += reward
    iters += 1

    return totalreward

# %%
def plot_cost_to_go(env, estimator, num_tiles=20):
    x = np.linspace(env.observation_space.low[0], env.observation_space.high[0], num=num_tiles)
    y = np.linspace(env.observation_space.low[1], env.observation_space.high[1], num=num_tiles)
    X, Y = np.meshgrid(x, y)
    # both X and Y will be of shape (num_tiles, num_tiles)
    Z = np.apply_along_axis(lambda _: -np.max(estimator.predict(_)), 2, np.dstack([X, Y]))
    # Z will also be of shape (num_tiles, num_tiles)

    fig = plt.figure(figsize=(10, 5))
    ax = fig.add_subplot(111, projection='3d')
    surf = ax.plot_surface(X, Y, Z,
        rstride=1, cstride=1, cmap=matplotlib.cm.coolwarm, vmin=-1.0, vmax=1.0)
    ax.set_xlabel('Position')
    ax.set_ylabel('Velocity')
    ax.set_zlabel('Cost-To-Go == -V(s)')
    ax.set_title("Cost-To-Go Function")
    fig.colorbar(surf)
    plt.show()


def plot_running_avg(totalrewards):
    N = len(totalrewards)
    running_avg = np.empty(N)
    for t in range(N):
    running_avg[t] = totalrewards[max(0, t-100):(t+1)].mean()
    plt.plot(running_avg)
    plt.title("Running Average")
    plt.show()

# %%
env = gym.make('MountainCar-v0')
ft = FeatureTransformer(env)
model = Model(env, ft, "constant")
gamma = 0.99

N = 300
show_plots = True
totalrewards = np.empty(N)
for n in range(N):
    # eps = 1.0/(0.1*n+1)
    # eps = 0.1*(0.97**n)
    # if n == 199:
    #     print("eps:", eps)
    eps = 1.0/np.sqrt(n+1)
    totalreward = play_one(model, env, eps, gamma)
    totalrewards[n] = totalreward
    if (n + 1) % 10 == 0:
        print("episode:", n, "total reward:", totalreward)
    print("avg reward for last 100 episodes:", totalrewards[-100:].mean())
    print("total steps:", -totalrewards.sum())

if show_plots:
    plt.plot(totalrewards)
    plt.title("Rewards")
    plt.show()

    plot_running_avg(totalrewards)

    # plot the optimal state-value function
    plot_cost_to_go(env, model)
# Out:
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 10000.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 10400.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 10664.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 10855.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 11148.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 11436.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 11664.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 11835.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 12041.0
# episode: 9 total reward: -219.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 12260.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 12439.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 12644.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 12872.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 13202.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 13460.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 13744.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 14090.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 14304.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 14710.0
# episode: 19 total reward: -304.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 15014.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 15224.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 15536.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 15780.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 16059.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 16272.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 16474.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 16651.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 16812.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 17045.0
# episode: 29 total reward: -242.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 17287.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 17505.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 17709.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 17923.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 18166.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 18419.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 18666.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 18990.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 19188.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 19496.0
# episode: 39 total reward: -245.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 19741.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 20038.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 20242.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 20500.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 20661.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 20861.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 21051.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 21207.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 21439.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 21647.0
# episode: 49 total reward: -264.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 21911.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 22221.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 22520.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 22776.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 23093.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 23405.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 23581.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 23913.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 24239.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 24559.0
# episode: 59 total reward: -134.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 24693.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 24931.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 25118.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 25525.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 25662.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 25949.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 26159.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 26392.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 26595.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 26848.0
# episode: 69 total reward: -207.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 27055.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 27275.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 27493.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 27621.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 27811.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 27995.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 28203.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 28339.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 28537.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 28750.0
# episode: 79 total reward: -155.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 28905.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 29097.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 29293.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 29481.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 29616.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 29939.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 30141.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 30308.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 30509.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 30691.0
# episode: 89 total reward: -221.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 30912.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 31034.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 31187.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 31469.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 31664.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 31867.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 32093.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 32218.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 32424.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 32688.0
# episode: 99 total reward: -195.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 32883.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 33036.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 33174.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 33368.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 33582.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 33742.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 33940.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 34125.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 34316.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 34499.0
# episode: 109 total reward: -175.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 34674.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 34865.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 35081.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 35232.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 35448.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 35598.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 35793.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 35949.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 36073.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 36263.0
# episode: 119 total reward: -216.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 36479.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 36650.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 36838.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 37010.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 37159.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 37335.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 37588.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 37806.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 37998.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 38147.0
# episode: 129 total reward: -151.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 38298.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 38499.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 38657.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 38806.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 38963.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 39112.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 39310.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 39768.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 40006.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 40156.0
# episode: 139 total reward: -163.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 40319.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 40466.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 40695.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 40914.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 41063.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 41224.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 41377.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 41520.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 41758.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 41905.0
# episode: 149 total reward: -200.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 42105.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 42260.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 42407.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 42553.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 42813.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 42964.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 43116.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 43266.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 43418.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 43567.0
# episode: 159 total reward: -157.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 43724.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 43876.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 44033.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 44190.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 44337.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 44495.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 44654.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 44809.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 45081.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 45226.0
# episode: 169 total reward: -150.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 45376.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 45530.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 45681.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 45910.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 46130.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 46272.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 46431.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 46599.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 46813.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 46963.0
# episode: 179 total reward: -146.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 47109.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 47337.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 47491.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 47644.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 47794.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 47949.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 48207.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 48359.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 48506.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 48664.0
# episode: 189 total reward: -221.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 48885.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 49144.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 49295.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 49443.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 49598.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 49822.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 49970.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 50213.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 50362.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 50515.0
# episode: 199 total reward: -219.0
# avg reward for last 100 episodes: 1.060997895729e-311
# total steps: 50734.0
# avg reward for last 100 episodes: -1.52
# total steps: 50886.0
# avg reward for last 100 episodes: -3.74
# total steps: 51108.0
# avg reward for last 100 episodes: -5.24
# total steps: 51258.0
# avg reward for last 100 episodes: -6.72
# total steps: 51406.0
# avg reward for last 100 episodes: -8.88
# total steps: 51622.0
# avg reward for last 100 episodes: -10.35
# total steps: 51769.0
# avg reward for last 100 episodes: -11.86
# total steps: 51920.0
# avg reward for last 100 episodes: -13.35
# total steps: 52069.0
# avg reward for last 100 episodes: -14.89
# total steps: 52223.0
# episode: 209 total reward: -292.0
# avg reward for last 100 episodes: -17.81
# total steps: 52515.0
# avg reward for last 100 episodes: -19.88
# total steps: 52722.0
# avg reward for last 100 episodes: -21.39
# total steps: 52873.0
# avg reward for last 100 episodes: -23.02
# total steps: 53036.0
# avg reward for last 100 episodes: -25.21
# total steps: 53255.0
# avg reward for last 100 episodes: -26.74
# total steps: 53408.0
# avg reward for last 100 episodes: -28.23
# total steps: 53557.0
# avg reward for last 100 episodes: -29.76
# total steps: 53710.0
# avg reward for last 100 episodes: -31.42
# total steps: 53876.0
# avg reward for last 100 episodes: -32.96
# total steps: 54030.0
# episode: 219 total reward: -213.0
# avg reward for last 100 episodes: -35.09
# total steps: 54243.0
# avg reward for last 100 episodes: -36.61
# total steps: 54395.0
# avg reward for last 100 episodes: -39.38
# total steps: 54672.0
# avg reward for last 100 episodes: -41.45
# total steps: 54879.0
# avg reward for last 100 episodes: -43.5
# total steps: 55084.0
# avg reward for last 100 episodes: -45.09
# total steps: 55243.0
# avg reward for last 100 episodes: -46.53
# total steps: 55387.0
# avg reward for last 100 episodes: -48.64
# total steps: 55598.0
# avg reward for last 100 episodes: -50.16
# total steps: 55750.0
# avg reward for last 100 episodes: -51.65
# total steps: 55899.0
# episode: 229 total reward: -150.0
# avg reward for last 100 episodes: -53.15
# total steps: 56049.0
# avg reward for last 100 episodes: -56.02
# total steps: 56336.0
# avg reward for last 100 episodes: -57.52
# total steps: 56486.0
# avg reward for last 100 episodes: -59.08
# total steps: 56642.0
# avg reward for last 100 episodes: -60.51
# total steps: 56785.0
# avg reward for last 100 episodes: -61.97
# total steps: 56931.0
# avg reward for last 100 episodes: -63.51
# total steps: 57085.0
# avg reward for last 100 episodes: -65.02
# total steps: 57236.0
# avg reward for last 100 episodes: -66.44
# total steps: 57378.0
# avg reward for last 100 episodes: -68.0
# total steps: 57534.0
# episode: 239 total reward: -212.0
# avg reward for last 100 episodes: -70.12
# total steps: 57746.0
# avg reward for last 100 episodes: -71.69
# total steps: 57903.0
# avg reward for last 100 episodes: -73.24
# total steps: 58058.0
# avg reward for last 100 episodes: -75.36
# total steps: 58270.0
# avg reward for last 100 episodes: -77.94
# total steps: 58528.0
# avg reward for last 100 episodes: -79.39
# total steps: 58673.0
# avg reward for last 100 episodes: -80.83
# total steps: 58817.0
# avg reward for last 100 episodes: -82.33
# total steps: 58967.0
# avg reward for last 100 episodes: -84.05
# total steps: 59139.0
# avg reward for last 100 episodes: -85.53
# total steps: 59287.0
# episode: 249 total reward: -148.0
# avg reward for last 100 episodes: -87.01
# total steps: 59435.0
# avg reward for last 100 episodes: -89.72
# total steps: 59706.0
# avg reward for last 100 episodes: -91.22
# total steps: 59856.0
# avg reward for last 100 episodes: -92.63
# total steps: 59997.0
# avg reward for last 100 episodes: -94.08
# total steps: 60142.0
# avg reward for last 100 episodes: -95.7
# total steps: 60304.0
# avg reward for last 100 episodes: -98.41
# total steps: 60575.0
# avg reward for last 100 episodes: -99.87
# total steps: 60721.0
# avg reward for last 100 episodes: -101.31
# total steps: 60865.0
# avg reward for last 100 episodes: -102.77
# total steps: 61011.0
# episode: 259 total reward: -313.0
# avg reward for last 100 episodes: -105.9
# total steps: 61324.0
# avg reward for last 100 episodes: -107.39
# total steps: 61473.0
# avg reward for last 100 episodes: -108.84
# total steps: 61618.0
# avg reward for last 100 episodes: -110.42
# total steps: 61776.0
# avg reward for last 100 episodes: -111.87
# total steps: 61921.0
# avg reward for last 100 episodes: -113.41
# total steps: 62075.0
# avg reward for last 100 episodes: -114.95
# total steps: 62229.0
# avg reward for last 100 episodes: -116.37
# total steps: 62371.0
# avg reward for last 100 episodes: -117.84
# total steps: 62518.0
# avg reward for last 100 episodes: -119.35
# total steps: 62669.0
# episode: 269 total reward: -162.0
# avg reward for last 100 episodes: -120.97
# total steps: 62831.0
# avg reward for last 100 episodes: -122.59
# total steps: 62993.0
# avg reward for last 100 episodes: -124.07
# total steps: 63141.0
# avg reward for last 100 episodes: -126.15
# total steps: 63349.0
# avg reward for last 100 episodes: -127.6
# total steps: 63494.0
# avg reward for last 100 episodes: -129.0
# total steps: 63634.0
# avg reward for last 100 episodes: -130.52
# total steps: 63786.0
# avg reward for last 100 episodes: -133.24
# total steps: 64058.0
# avg reward for last 100 episodes: -134.68
# total steps: 64202.0
# avg reward for last 100 episodes: -136.28
# total steps: 64362.0
# episode: 279 total reward: -145.0
# avg reward for last 100 episodes: -137.73
# total steps: 64507.0
# avg reward for last 100 episodes: -139.45
# total steps: 64679.0
# avg reward for last 100 episodes: -140.88
# total steps: 64822.0
# avg reward for last 100 episodes: -143.36
# total steps: 65070.0
# avg reward for last 100 episodes: -144.76
# total steps: 65210.0
# avg reward for last 100 episodes: -146.94
# total steps: 65428.0
# avg reward for last 100 episodes: -148.62
# total steps: 65596.0
# avg reward for last 100 episodes: -150.28
# total steps: 65762.0
# avg reward for last 100 episodes: -151.79
# total steps: 65913.0
# avg reward for last 100 episodes: -153.73
# total steps: 66107.0
# episode: 289 total reward: -151.0
# avg reward for last 100 episodes: -155.24
# total steps: 66258.0
# avg reward for last 100 episodes: -156.87
# total steps: 66421.0
# avg reward for last 100 episodes: -158.36
# total steps: 66570.0
# avg reward for last 100 episodes: -159.79
# total steps: 66713.0
# avg reward for last 100 episodes: -161.28
# total steps: 66862.0
# avg reward for last 100 episodes: -162.79
# total steps: 67013.0
# avg reward for last 100 episodes: -164.63
# total steps: 67197.0
# avg reward for last 100 episodes: -166.13
# total steps: 67347.0
# avg reward for last 100 episodes: -167.55
# total steps: 67489.0
# avg reward for last 100 episodes: -169.0
# total steps: 67634.0
# episode: 299 total reward: -93.0
# avg reward for last 100 episodes: -169.93
# total steps: 67727.0
